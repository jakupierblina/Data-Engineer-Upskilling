# %%
# !pip install matplotlib pandas seaborn

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Out:
# Requirement already satisfied: matplotlib in /home/blina/anaconda3/lib/python3.9/site-packages (3.8.0)
# Requirement already satisfied: pandas in /home/blina/anaconda3/lib/python3.9/site-packages (2.1.4)
# Requirement already satisfied: seaborn in /home/blina/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in /home/blina/anaconda3/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/blina/anaconda3/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in /home/blina/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Data Preparation

# %%
data_path = 'data/'
activity = pd.DataFrame()
for dirname, _, filenames in os.walk(data_path):
    for filename in filenames:
        if filename == 'scores.csv':
            continue
        tmp = pd.read_csv(os.path.join(dirname, filename))
        tmp['timestamp'] = pd.to_datetime(tmp['timestamp'])
        tmp['number'] = filename[:-4]
        tmp = tmp.drop(columns=['date'])
        activity = pd.concat([activity, tmp])

# %%
activity
# Out:
#                 timestamp  activity        number
# 0     2004-02-17 09:00:00         7    control_22
# 1     2004-02-17 09:01:00         9    control_22
# 2     2004-02-17 09:02:00         9    control_22
# 3     2004-02-17 09:03:00         7    control_22
# 4     2004-02-17 09:04:00         9    control_22
# ...                   ...       ...           ...
# 41842 2005-10-21 11:22:00         0  condition_16
# 41843 2005-10-21 11:23:00         0  condition_16
# 41844 2005-10-21 11:24:00         0  condition_16
# 41845 2005-10-21 11:25:00         0  condition_16
# 41846 2005-10-21 11:26:00         3  condition_16
#
# [1571706 rows x 3 columns]

# %%
scores_path = 'data/scores.csv'
df = pd.read_csv(scores_path)

# %%
df
# Out:
#           number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0    condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1    condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2    condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3    condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4    condition_5    13       2  50-54      2.0      2.0        2.0  11-15
# 5    condition_6     7       1  35-39      2.0      2.0        2.0   6-10
# 6    condition_7    11       1  20-24      1.0      NaN        2.0  11-15
# 7    condition_8     5       2  25-29      2.0      NaN        2.0  11-15
# 8    condition_9    13       2  45-49      1.0      NaN        2.0   6-10
# 9   condition_10     9       2  45-49      2.0      2.0        2.0   6-10
# 10  condition_11    14       1  45-49      2.0      2.0        2.0   6-10
# 11  condition_12    12       2  40-44      1.0      2.0        2.0   6-10
# 12  condition_13    14       2  35-39      1.0      2.0        2.0  11-15
# 13  condition_14    14       1  60-64      1.0      2.0        2.0   6-10
# 14  condition_15    13       2  55-59      2.0      2.0        2.0  11-15
# 15  condition_16    16       1  45-49      2.0      2.0        2.0  11-15
# 16  condition_17    13       1  50-54      1.0      2.0        2.0   6-10
# 17  condition_18    13       2  40-44      3.0      2.0        2.0  11-15
# 18  condition_19    13       2  50-54      2.0      2.0        1.0  16-20
# 19  condition_20    13       1  30-34      2.0      1.0        1.0   6-10
# 20  condition_21    13       2  35-39      2.0      2.0        1.0   6-10
# 21  condition_22    14       1  65-69      2.0      2.0        1.0
# 22  condition_23    16       1  30-34      2.0      2.0        1.0  16-20
# 23     control_1     8       2  25-29      NaN      NaN        NaN    NaN
# 24     control_2    20       1  30-34      NaN      NaN        NaN
# 25     control_3    12       2  30-34      NaN      NaN        NaN
# 26     control_4    13       1  25-29      NaN      NaN        NaN
# 27     control_5    13       1  30-34      NaN      NaN        NaN
# 28     control_6    13       1  25-29      NaN      NaN        NaN
# 29     control_7    13       1  20-24      NaN      NaN        NaN
# 30     control_8    13       2  40-44      NaN      NaN        NaN
# 31     control_9    13       2  30-34      NaN      NaN        NaN
# 32    control_10     8       1  30-34      NaN      NaN        NaN
# 33    control_11    13       1  45-49      NaN      NaN        NaN
# 34    control_12    14       1  60-64      NaN      NaN        NaN
# 35    control_13    13       1  50-54      NaN      NaN        NaN    NaN
# 36    control_14    13       1  50-54      NaN      NaN        NaN
# 37    control_15    11       1  45-49      NaN      NaN        NaN
# 38    control_16    13       2  40-44      NaN      NaN        NaN
# 39    control_17     9       1  45-49      NaN      NaN        NaN
# 40    control_18    13       2  20-24      NaN      NaN        NaN
# 41    control_19    13       1  50-54      NaN      NaN        NaN
# 42    control_20    13       1  35-39      NaN      NaN        NaN
# 43    control_21     8       1  50-54      NaN      NaN        NaN
# 44    control_22    13       1  25-29      NaN      NaN        NaN
# 45    control_23    13       1  20-24      NaN      NaN        NaN
# 46    control_24    13       2  20-24      NaN      NaN        NaN
# 47    control_25    13       1  65-69      NaN      NaN        NaN
# 48    control_26    13       1  35-39      NaN      NaN        NaN
# 49    control_27    13       2  50-54      NaN      NaN        NaN
# 50    control_28    16       2  45-49      NaN      NaN        NaN
# 51    control_29    13       2  50-54      NaN      NaN        NaN
# 52    control_30     9       2  35-39      NaN      NaN        NaN
# 53    control_31    13       1  20-24      NaN      NaN        NaN
# 54    control_32    14       2  25-29      NaN      NaN        NaN
#
#     marriage  work  madrs1  madrs2
# 0        1.0   2.0    19.0    19.0
# 1        2.0   2.0    24.0    11.0
# 2        2.0   2.0    24.0    25.0
# 3        1.0   1.0    20.0    16.0
# 4        2.0   2.0    26.0    26.0
# 5        1.0   2.0    18.0    15.0
# 6        2.0   1.0    24.0    25.0
# 7        1.0   2.0    20.0    16.0
# 8        1.0   2.0    26.0    26.0
# 9        1.0   2.0    28.0    21.0
# 10       1.0   2.0    24.0    24.0
# 11       2.0   2.0    25.0    21.0
# 12       2.0   2.0    18.0    13.0
# 13       2.0   2.0    28.0    19.0
# 14       1.0   1.0    14.0    18.0
# 15       1.0   2.0    13.0    17.0
# 16       1.0   2.0    17.0    15.0
# 17       2.0   2.0    18.0    15.0
# 18       2.0   2.0    26.0    21.0
# 19       1.0   2.0    27.0    25.0
# 20       2.0   2.0    26.0    21.0
# 21       2.0   2.0    29.0    28.0
# 22       2.0   2.0    29.0    23.0
# 23       NaN   NaN     NaN     NaN
# 24       NaN   NaN     NaN     NaN
# 25       NaN   NaN     NaN     NaN
# 26       NaN   NaN     NaN     NaN
# 27       NaN   NaN     NaN     NaN
# 28       NaN   NaN     NaN     NaN
# 29       NaN   NaN     NaN     NaN
# 30       NaN   NaN     NaN     NaN
# 31       NaN   NaN     NaN     NaN
# 32       NaN   NaN     NaN     NaN
# 33       NaN   NaN     NaN     NaN
# 34       NaN   NaN     NaN     NaN
# 35       NaN   NaN     NaN     NaN
# 36       NaN   NaN     NaN     NaN
# 37       NaN   NaN     NaN     NaN
# 38       NaN   NaN     NaN     NaN
# 39       NaN   NaN     NaN     NaN
# 40       NaN   NaN     NaN     NaN
# 41       NaN   NaN     NaN     NaN
# 42       NaN   NaN     NaN     NaN
# 43       NaN   NaN     NaN     NaN
# 44       NaN   NaN     NaN     NaN
# 45       NaN   NaN     NaN     NaN
# 46       NaN   NaN     NaN     NaN
# 47       NaN   NaN     NaN     NaN
# 48       NaN   NaN     NaN     NaN
# 49       NaN   NaN     NaN     NaN
# 50       NaN   NaN     NaN     NaN
# 51       NaN   NaN     NaN     NaN
# 52       NaN   NaN     NaN     NaN
# 53       NaN   NaN     NaN     NaN
# 54       NaN   NaN     NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   number     55 non-null     object
#  1   days       55 non-null     int64
#  2   gender     55 non-null     int64
#  3   age        55 non-null     object
#  4   afftype    23 non-null     float64
#  5   melanch    20 non-null     float64
#  6   inpatient  23 non-null     float64
#  7   edu        53 non-null     object
#  8   marriage   23 non-null     float64
#  9   work       23 non-null     float64
#  10  madrs1     23 non-null     float64
#  11  madrs2     23 non-null     float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 5.3+ KB

# %%
print(f'age unique: {df.age.unique()}\nedo unique: {df.edu.unique()}')
# Out:
# age unique: [35 40 45 25 50 20 60 55 30 65]
# edo unique: [ 1.  2.  3. nan]

# %%
df.describe()
# Out:
#             days     gender        age    afftype    melanch  inpatient  \
# count  55.000000  55.000000  55.000000  23.000000  20.000000  23.000000
# mean   12.600000   1.454545  38.363636   1.739130   1.950000   1.782609
# std     2.491467   0.502519  12.249510   0.540824   0.223607   0.421741
# min     5.000000   1.000000  20.000000   1.000000   1.000000   1.000000
# 25%    13.000000   1.000000  30.000000   1.000000   2.000000   2.000000
# 50%    13.000000   1.000000  40.000000   2.000000   2.000000   2.000000
# 75%    13.000000   2.000000  47.500000   2.000000   2.000000   2.000000
# max    20.000000   2.000000  65.000000   3.000000   2.000000   2.000000
#
#              edu   marriage       work     madrs1     madrs2  condition  \
# count  22.000000  23.000000  23.000000  23.000000  23.000000  55.000000
# mean    1.545455   1.521739   1.869565  22.739130  20.000000   0.418182
# std     0.670982   0.510754   0.344350   4.797892   4.729021   0.497807
# min     1.000000   1.000000   1.000000  13.000000  11.000000   0.000000
# 25%     1.000000   1.000000   2.000000  18.500000  16.000000   0.000000
# 50%     1.000000   2.000000   2.000000  24.000000  21.000000   0.000000
# 75%     2.000000   2.000000   2.000000  26.000000  24.500000   1.000000
# max     3.000000   2.000000   2.000000  29.000000  28.000000   1.000000
#
#          activity  madrs_delta
# count   55.000000    23.000000
# mean   189.862636    -2.739130
# std     80.547674     3.968253
# min     54.697992   -13.000000
# 25%    142.301726    -5.000000
# 50%    172.288577    -3.000000
# 75%    243.378252     0.000000
# max    398.883456     4.000000

# %%
df

# %%
features_num = ['days', 'madrs1', 'madrs2', 'madrs_delta', 'activity']
features_cat = ['age', 'gender', 'afftype', 'melanch', 'inpatient', 'edu', 'marriage', 'work']

# %%
cond_df = df[df.condition ==1]

# %%
cond_df.isna().sum()
# Out:
# number         0
# days           0
# gender         0
# age            0
# afftype        0
# melanch        3
# inpatient      0
# edu            1
# marriage       0
# work           0
# madrs1         0
# madrs2         0
# condition      0
# activity       0
# madrs_delta    0
# dtype: int64

# %%
cond_df = cond_df.fillna(0)
cond_df[features_num]
# Out:
#     days  madrs1  madrs2  madrs_delta    activity
# 0     11    19.0    19.0          0.0  146.948030
# 1     18    24.0    11.0        -13.0  153.664748
# 2     13    24.0    25.0          1.0  265.299704
# 3     13    20.0    16.0         -4.0  274.866998
# 4     13    26.0    26.0          0.0  167.245987
# 5      7    18.0    15.0         -3.0  196.416414
# 6     11    24.0    25.0          1.0  261.805502
# 7      5    20.0    16.0         -4.0  184.934453
# 8     13    26.0    26.0          0.0  178.773304
# 9      9    28.0    21.0         -7.0  289.647228
# 10    14    24.0    24.0          0.0  129.383036
# 11    12    25.0    21.0         -4.0  151.444846
# 12    14    18.0    13.0         -5.0  221.348746
# 13    14    28.0    19.0         -9.0   75.049894
# 14    13    14.0    18.0          4.0  109.534060
# 15    16    13.0    17.0          4.0  146.442397
# 16    13    17.0    15.0         -2.0   85.842181
# 17    13    18.0    15.0         -3.0   71.104090
# 18    13    26.0    21.0         -5.0  157.240215
# 19    13    27.0    25.0         -2.0   54.697992
# 20    13    26.0    21.0         -5.0   79.480061
# 21    14    29.0    28.0         -1.0  161.756063
# 22    16    29.0    23.0         -6.0  202.619088

# %%
sns.pairplot(cond_df[features_num], kind='reg')
# Out:
# /home/blina/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/blina/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/blina/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/blina/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/blina/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
rows = len(features_cat)
fig, axes = plt.subplots(rows, 3, figsize=(15, 5*rows))
for ax, f in zip(axes, features_cat):
    for i, madrs in enumerate(['madrs1', 'madrs2', 'madrs_delta']):
        sns.boxplot(data=cond_df, x=f, y=madrs, ax=ax[i])
        ax[i].set_title(f'{madrs} vs {f}')
        ax[i].grid()
fig.tight_layout()

# %%
plt.figure(figsize=(10,9))
sns.heatmap(
    cond_df.drop(columns=['number', 'condition']).corr(),
    annot=True, fmt='.2f',
    linewidth=0.5,
    cmap='coolwarm',
    vmin=-1, vmax=1
)
plt.title(f'Correlation heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation heatmap')

# %% [markdown]
# ### Interactive parallel coordinates plot¶

# %%
# !pip install hiplot
# Out:
# Collecting hiplot
#   Downloading hiplot-0.1.33-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: ipython>=7.0.1 in /home/blina/anaconda3/lib/python3.9/site-packages (from hiplot) (8.15.0)
# Requirement already satisfied: flask in /home/blina/anaconda3/lib/python3.9/site-packages (from hiplot) (2.2.5)
# Collecting flask-compress (from hiplot)
#   Downloading Flask_Compress-1.15-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: beautifulsoup4 in /home/blina/anaconda3/lib/python3.9/site-packages (from hiplot) (4.12.2)
# Requirement already satisfied: backcall in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (0.2.0)
# Requirement already satisfied: decorator in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (0.1.6)
# Requirement already satisfied: pickleshare in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (2.15.1)
# Requirement already satisfied: stack-data in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (5.7.1)
# Requirement already satisfied: typing-extensions in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (4.9.0)
# Requirement already satisfied: exceptiongroup in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/blina/anaconda3/lib/python3.9/site-packages (from ipython>=7.0.1->hiplot) (4.8.0)
# Requirement already satisfied: soupsieve>1.2 in /home/blina/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->hiplot) (2.5)
# Requirement already satisfied: Werkzeug>=2.2.2 in /home/blina/anaconda3/lib/python3.9/site-packages (from flask->hiplot) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from flask->hiplot) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from flask->hiplot) (2.0.1)
# Requirement already satisfied: click>=8.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from flask->hiplot) (8.1.7)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from flask->hiplot) (7.0.1)
# Requirement already satisfied: brotli in /home/blina/anaconda3/lib/python3.9/site-packages (from flask-compress->hiplot) (1.0.9)
# Requirement already satisfied: zstandard in /home/blina/anaconda3/lib/python3.9/site-packages (from flask-compress->hiplot) (0.19.0)
# Requirement already satisfied: zipp>=0.5 in /home/blina/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask->hiplot) (3.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.0.1->hiplot) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/blina/anaconda3/lib/python3.9/site-packages (from Jinja2>=3.0->flask->hiplot) (2.1.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/blina/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.0.1->hiplot) (0.7.0)
# Requirement already satisfied: wcwidth in /home/blina/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.0.1->hiplot) (0.2.5)
# Requirement already satisfied: executing in /home/blina/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.0.1->hiplot) (0.8.3)
# Requirement already satisfied: asttokens in /home/blina/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.0.1->hiplot) (2.0.5)
# Requirement already satisfied: pure-eval in /home/blina/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=7.0.1->hiplot) (0.2.2)
# Requirement already satisfied: six in /home/blina/anaconda3/lib/python3.9/site-packages (from asttokens->stack-data->ipython>=7.0.1->hiplot) (1.16.0)
# Downloading hiplot-0.1.33-py3-none-any.whl (863 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.2/863.2 kB 7.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading Flask_Compress-1.15-py3-none-any.whl (8.6 kB)
# Installing collected packages: flask-compress, hiplot
# Successfully installed flask-compress-1.15 hiplot-0.1.33

# %%
import hiplot as hip

# %%
cols = [
    'condition', 'gender', 'days', 'age', 'activity',
    # The following columns are only included for the condition group
    # 'afftype', 'melanch', 'inpatient', 'edu', 'marriage', 'work', 'madrs1', 'madrs_delta'
]
exp = hip.Experiment.from_iterable(df[cols[::-1]].to_dict(orient='records'))
exp.colorby = 'condition'
exp.display()
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta http-equiv="Content-Type" content="text/html;charset=utf-8"/>
#     <title>HiPlot</title>
#     <link rel="icon" href="static/icon.png" />
#   </head>
#   <body style="margin:0px">
#     <div id="hiplot_30434bebbe94431fb00fc244f7f3abdf" style="background-color: white"><div style="text-align: center">Loading HiPlot...</div>
#       <noscript>
#         HiPlot needs JavaScript to run
#       </noscript>
#     </div>
#
#     <script  type="text/javascript" ></script>
#     <script type="text/javascript">
#     function _hiplot_setup() {
#       if (typeof hiplot == "undefined") {
#         console.info("waiting for HiPlot bundle to be loaded...");
#         setTimeout(_hiplot_setup, 1000);
#         return;
#       }
#       var options = {};
#       /*ON_LOAD_SCRIPT_INJECT*/
# const comm_id = "comm_461480";
# try {
#     console.log("Setting up communication channel with Jupyter: ", comm_id);
#     const comm = Jupyter.notebook.kernel.comm_manager.new_comm(comm_id, {'type': 'hello'});
#     var comm_message_id = 0;
#     function send_data_change(type, data) {
#         comm.send({
#             'type': type,
#             'message_id': comm_message_id,
#             'data': data,
#         });
#         comm_message_id += 1;
#     };
#     Object.assign(options, {"onChange": {
#         "selected_uids": send_data_change,
#         "brush_extents": send_data_change,
#     }});
# }
# catch(err) {
#     console.warn('Unable to create Javascript <-> Python communication channel' +
#         ' (are you in a Jupyter notebook? Jupyter labs is *not* supported!)');
# }
#
#         Object.assign(options, eval('(' + "{\"dataProviderName\": \"none\", \"experiment\": {\"parameters_definition\": {}, \"colormap\": \"interpolateTurbo\", \"colorby\": \"condition\", \"weightcolumn\": null, \"display_data\": {}, \"enabled_displays\": [\"PARALLEL_PLOT\", \"XY\", \"DISTRIBUTION\", \"TABLE\"], \"datapoints\": [{\"uid\": \"0\", \"values\": {\"activity\": 146.94802959903632, \"age\": 35, \"days\": 11, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"1\", \"values\": {\"activity\": 153.66474849714842, \"age\": 40, \"days\": 18, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"2\", \"values\": {\"activity\": 265.29970436068, \"age\": 45, \"days\": 13, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"3\", \"values\": {\"activity\": 274.8669975876786, \"age\": 25, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"4\", \"values\": {\"activity\": 167.24598706555622, \"age\": 50, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"5\", \"values\": {\"activity\": 196.41641394111883, \"age\": 35, \"days\": 7, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"6\", \"values\": {\"activity\": 261.8055016910936, \"age\": 20, \"days\": 11, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"7\", \"values\": {\"activity\": 184.93445256230893, \"age\": 25, \"days\": 5, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"8\", \"values\": {\"activity\": 178.7733044591003, \"age\": 45, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"9\", \"values\": {\"activity\": 289.64722802134077, \"age\": 45, \"days\": 9, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"10\", \"values\": {\"activity\": 129.38303610265334, \"age\": 45, \"days\": 14, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"11\", \"values\": {\"activity\": 151.4448458030433, \"age\": 40, \"days\": 12, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"12\", \"values\": {\"activity\": 221.34874565804708, \"age\": 35, \"days\": 14, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"13\", \"values\": {\"activity\": 75.04989374480273, \"age\": 60, \"days\": 14, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"14\", \"values\": {\"activity\": 109.53406019515323, \"age\": 55, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"15\", \"values\": {\"activity\": 146.44239730446628, \"age\": 45, \"days\": 16, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"16\", \"values\": {\"activity\": 85.84218104128931, \"age\": 50, \"days\": 13, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"17\", \"values\": {\"activity\": 71.10408956762075, \"age\": 40, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"18\", \"values\": {\"activity\": 157.24021478027413, \"age\": 50, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"19\", \"values\": {\"activity\": 54.697992030022824, \"age\": 30, \"days\": 13, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"20\", \"values\": {\"activity\": 79.48006052618734, \"age\": 35, \"days\": 13, \"gender\": 2, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"21\", \"values\": {\"activity\": 161.75606283299652, \"age\": 65, \"days\": 14, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"22\", \"values\": {\"activity\": 202.61908845481975, \"age\": 30, \"days\": 16, \"gender\": 1, \"condition\": 1}, \"from_uid\": null}, {\"uid\": \"23\", \"values\": {\"activity\": 98.54507759973649, \"age\": 25, \"days\": 8, \"gender\": 2, \"condition\": 0}, \"from_uid\": null}, {\"uid\": \"24\", \"values\": {\"activity\": 398.8834556604073, \"age\": 30, \"days\": 20, \"gender\": 1, \"condition\": 0}, \"from_uid\": null}, {\"uid\": \"25\", \"v ...
